-- %% [markdown]
-- # [BookStore]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [BookStore]    Script Date: 2022/12/27 下午 05:34:27 ******/
CREATE DATABASE [BookStore]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'BookStore', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\BookStore.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'BookStore_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\BookStore_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [BookStore] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [BookStore].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [BookStore] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [BookStore] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [BookStore] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [BookStore] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [BookStore] SET ARITHABORT OFF 
GO
ALTER DATABASE [BookStore] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [BookStore] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [BookStore] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [BookStore] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [BookStore] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [BookStore] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [BookStore] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [BookStore] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [BookStore] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [BookStore] SET  DISABLE_BROKER 
GO
ALTER DATABASE [BookStore] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [BookStore] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [BookStore] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [BookStore] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [BookStore] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [BookStore] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [BookStore] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [BookStore] SET RECOVERY FULL 
GO
ALTER DATABASE [BookStore] SET  MULTI_USER 
GO
ALTER DATABASE [BookStore] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [BookStore] SET DB_CHAINING OFF 
GO
ALTER DATABASE [BookStore] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [BookStore] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [BookStore] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [BookStore] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'BookStore', N'ON'
GO
ALTER DATABASE [BookStore] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [bookstoreLogin]

-- %%
USE [BookStore]
GO

-- %%
/****** Object:  User [bookstoreLogin]    Script Date: 2022/12/27 下午 05:34:27 ******/
CREATE USER [bookstoreLogin] FOR LOGIN [bookstoreLogin] WITH DEFAULT_SCHEMA=[dbo]
GO

-- %%
ALTER ROLE [db_owner] ADD MEMBER [bookstoreLogin]
GO

-- %% [markdown]
-- # [dbo].[CartItems]

-- %%
/****** Object:  Table [dbo].[CartItems]    Script Date: 2022/12/27 下午 05:34:27 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CartItems](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CartId] [int] NOT NULL,
	[ProductId] [int] NOT NULL,
	[Qty] [int] NOT NULL,
 CONSTRAINT [PK_CartItems] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Carts]

-- %%
/****** Object:  Table [dbo].[Carts]    Script Date: 2022/12/27 下午 05:34:27 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Carts](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[MemberAccount] [nvarchar](30) NOT NULL,
 CONSTRAINT [PK_Carts] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Categories]

-- %%
/****** Object:  Table [dbo].[Categories]    Script Date: 2022/12/27 下午 05:34:27 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Categories](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Name] [nvarchar](30) NOT NULL,
	[DisplayOrder] [int] NOT NULL,
 CONSTRAINT [PK_Categories] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Members]

-- %%
/****** Object:  Table [dbo].[Members]    Script Date: 2022/12/27 下午 05:34:27 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Members](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Account] [nvarchar](30) NOT NULL,
	[EncryptedPassword] [nvarchar](70) NOT NULL,
	[Email] [nvarchar](256) NOT NULL,
	[Name] [nvarchar](30) NOT NULL,
	[Mobile] [varchar](10) NULL,
	[IsConfirmed] [bit] NOT NULL,
	[ConfirmCode] [nvarchar](50) NULL,
 CONSTRAINT [PK_Members] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[OrderItems]

-- %%
/****** Object:  Table [dbo].[OrderItems]    Script Date: 2022/12/27 下午 05:34:27 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[OrderItems](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[OrderId] [int] NOT NULL,
	[ProductId] [int] NOT NULL,
	[ProductName] [nvarchar](50) NOT NULL,
	[Price] [int] NOT NULL,
	[Qty] [int] NOT NULL,
	[SubTotal] [int] NOT NULL,
 CONSTRAINT [PK_OrderItems] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Orders]

-- %%
/****** Object:  Table [dbo].[Orders]    Script Date: 2022/12/27 下午 05:34:27 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Orders](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[MemberId] [int] NOT NULL,
	[Total] [int] NOT NULL,
	[CreatedTime] [datetime] NOT NULL,
	[Status] [int] NOT NULL,
	[RequestRefund] [bit] NOT NULL,
	[RequestRefundTime] [datetime] NULL,
	[Receiver] [nvarchar](30) NOT NULL,
	[Address] [nvarchar](200) NOT NULL,
	[CellPhone] [varchar](10) NOT NULL,
 CONSTRAINT [PK_Orders] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Products]

-- %%
/****** Object:  Table [dbo].[Products]    Script Date: 2022/12/27 下午 05:34:27 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Products](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CategoryId] [int] NOT NULL,
	[Name] [nvarchar](50) NOT NULL,
	[Price] [int] NOT NULL,
	[Description] [nvarchar](3000) NOT NULL,
	[Status] [bit] NOT NULL,
	[ProductImage] [nvarchar](70) NOT NULL,
	[Stock] [int] NOT NULL,
 CONSTRAINT [PK_Products] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Categories]

-- %%
SET IDENTITY_INSERT [dbo].[Categories] ON 
INSERT [dbo].[Categories] ([Id], [Name], [DisplayOrder]) VALUES (1, N'3C', 10)
INSERT [dbo].[Categories] ([Id], [Name], [DisplayOrder]) VALUES (2, N'家電', 20)
INSERT [dbo].[Categories] ([Id], [Name], [DisplayOrder]) VALUES (3, N'生活用品', 30)
SET IDENTITY_INSERT [dbo].[Categories] OFF
GO

-- %% [markdown]
-- # [dbo].[Members]

-- %%
SET IDENTITY_INSERT [dbo].[Members] ON 
INSERT [dbo].[Members] ([Id], [Account], [EncryptedPassword], [Email], [Name], [Mobile], [IsConfirmed], [ConfirmCode]) VALUES (1, N'999', N'F5478EBD0ECCDE7FB5911BB0C1D4BE0E0422FE150E3E4165338CE3A74B6BF439', N'789', N'weqwe', N'0987879654', 1, NULL)
SET IDENTITY_INSERT [dbo].[Members] OFF
GO

-- %% [markdown]
-- # [dbo].[Products]

-- %%
SET IDENTITY_INSERT [dbo].[Products] ON 
INSERT [dbo].[Products] ([Id], [CategoryId], [Name], [Price], [Description], [Status], [ProductImage], [Stock]) VALUES (1, 1, N'HP Printer', 3000, N'description', 1, N'printer.jpg', 100)
INSERT [dbo].[Products] ([Id], [CategoryId], [Name], [Price], [Description], [Status], [ProductImage], [Stock]) VALUES (2, 1, N'華碩A320 桌機', 20000, N'description', 1, N'acerPC.jpg', 100)
INSERT [dbo].[Products] ([Id], [CategoryId], [Name], [Price], [Description], [Status], [ProductImage], [Stock]) VALUES (3, 1, N'華碩 Zenbook 14 UX3402ZA', 34900, N'description', 1, N'zenbook.jpg', 100)
INSERT [dbo].[Products] ([Id], [CategoryId], [Name], [Price], [Description], [Status], [ProductImage], [Stock]) VALUES (4, 2, N'Dyson Cyclone V10 Fluffy SV12 無線吸塵器', 12900, N'description', 1, N'a.jpg', 100)
INSERT [dbo].[Products] ([Id], [CategoryId], [Name], [Price], [Description], [Status], [ProductImage], [Stock]) VALUES (5, 2, N'SANSUI 山水 1.8L大容量304不銹鋼電茶壺二入組', 788, N'description', 1, N'a.jpg', 100)
INSERT [dbo].[Products] ([Id], [CategoryId], [Name], [Price], [Description], [Status], [ProductImage], [Stock]) VALUES (6, 2, N'大日 Dainichi 煤油暖氣機', 10900, N'description', 1, N'a.jpg', 100)
INSERT [dbo].[Products] ([Id], [CategoryId], [Name], [Price], [Description], [Status], [ProductImage], [Stock]) VALUES (7, 2, N'PHILIPS 飛利浦  智能護齦音波震動牙刷 HX6803/02', 2490, N'description', 1, N'a.jpg', 100)
INSERT [dbo].[Products] ([Id], [CategoryId], [Name], [Price], [Description], [Status], [ProductImage], [Stock]) VALUES (8, 3, N'Boden-奧洛4尺多功能收納升降大茶几', 5599, N'description', 1, N'a.jpg', 100)
INSERT [dbo].[Products] ([Id], [CategoryId], [Name], [Price], [Description], [Status], [ProductImage], [Stock]) VALUES (9, 3, N'Flexispot 單螢幕懸浮旋臂支架 - 黑色', 1912, N'description', 1, N'a.jpg', 100)
INSERT [dbo].[Products] ([Id], [CategoryId], [Name], [Price], [Description], [Status], [ProductImage], [Stock]) VALUES (10, 3, N'Flexispot 簡易式氣壓升降工作台', 3390, N'description', 1, N'a.jpg', 100)
INSERT [dbo].[Products] ([Id], [CategoryId], [Name], [Price], [Description], [Status], [ProductImage], [Stock]) VALUES (11, 3, N'TOTO TCF23710ATW C2 溫水洗淨便座', 8990, N'description', 1, N'a.jpg', 100)
INSERT [dbo].[Products] ([Id], [CategoryId], [Name], [Price], [Description], [Status], [ProductImage], [Stock]) VALUES (12, 3, N'象印*0.82L*SLiT不鏽鋼真空保溫瓶', 690, N'description', 1, N'a.jpg', 100)
SET IDENTITY_INSERT [dbo].[Products] OFF
GO

-- %% [markdown]
-- # [IX_Members]

-- %%
SET ANSI_PADDING ON
GO
/****** Object:  Index [IX_Members]    Script Date: 2022/12/27 下午 05:34:27 ******/
CREATE UNIQUE NONCLUSTERED INDEX [IX_Members] ON [dbo].[Members]
(
	[Account] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, DROP_EXISTING = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF_Orders_CreatedTime]

-- %%
ALTER TABLE [dbo].[Orders] ADD  CONSTRAINT [DF_Orders_CreatedTime]  DEFAULT (getdate()) FOR [CreatedTime]
GO

-- %% [markdown]
-- # [DF_Orders_RequestRefund]

-- %%
ALTER TABLE [dbo].[Orders] ADD  CONSTRAINT [DF_Orders_RequestRefund]  DEFAULT ((0)) FOR [RequestRefund]
GO

-- %% [markdown]
-- # [DF_Products_Status]

-- %%
ALTER TABLE [dbo].[Products] ADD  CONSTRAINT [DF_Products_Status]  DEFAULT ((1)) FOR [Status]
GO

-- %% [markdown]
-- # [FK_CartItems_Carts]

-- %%
ALTER TABLE [dbo].[CartItems]  WITH CHECK ADD  CONSTRAINT [FK_CartItems_Carts] FOREIGN KEY([ProductId])
REFERENCES [dbo].[Products] ([Id])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[CartItems] CHECK CONSTRAINT [FK_CartItems_Carts]
GO

-- %% [markdown]
-- # [FK_OrderItems_Orders]

-- %%
ALTER TABLE [dbo].[OrderItems]  WITH CHECK ADD  CONSTRAINT [FK_OrderItems_Orders] FOREIGN KEY([OrderId])
REFERENCES [dbo].[Orders] ([Id])
GO
ALTER TABLE [dbo].[OrderItems] CHECK CONSTRAINT [FK_OrderItems_Orders]
GO

-- %% [markdown]
-- # [FK_OrderItems_Products]

-- %%
ALTER TABLE [dbo].[OrderItems]  WITH CHECK ADD  CONSTRAINT [FK_OrderItems_Products] FOREIGN KEY([ProductId])
REFERENCES [dbo].[Products] ([Id])
GO
ALTER TABLE [dbo].[OrderItems] CHECK CONSTRAINT [FK_OrderItems_Products]
GO

-- %% [markdown]
-- # [FK_Products_Categories]

-- %%
ALTER TABLE [dbo].[Products]  WITH CHECK ADD  CONSTRAINT [FK_Products_Categories] FOREIGN KEY([CategoryId])
REFERENCES [dbo].[Categories] ([Id])
GO
ALTER TABLE [dbo].[Products] CHECK CONSTRAINT [FK_Products_Categories]
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'1=訂單成立, 2=已結案, -1=已退訂' , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'TABLE',@level1name=N'Orders', @level2type=N'COLUMN',@level2name=N'Status'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'客戶是否提出退訂要求' , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'TABLE',@level1name=N'Orders', @level2type=N'COLUMN',@level2name=N'RequestRefund'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'1=可購買;0=已下架' , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'TABLE',@level1name=N'Products', @level2type=N'COLUMN',@level2name=N'Status'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'庫存量' , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'TABLE',@level1name=N'Products', @level2type=N'COLUMN',@level2name=N'Stock'
GO

-- %% [markdown]
-- # [BookStore]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [BookStore] SET  READ_WRITE 
GO
